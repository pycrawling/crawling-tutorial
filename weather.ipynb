# %%
import urllib
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')

# %%
r.status
# Out:
# 200

# %%
r

# %%
r.read(500)
# Out:
# b'<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>\r\n<description>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xeb\x82\xa0\xec\x94\xa8 \xec\x9b\xb9\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4</description>\r\n<language>ko</language>\r\n<generator>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</generator>\r\n<pubDate>2019\xeb\x85\x84 05\xec\x9b\x94 17\xec\x9d\xbc (\xea\xb8\x88)\xec\x9a\x94\xec\x9d\xbc 18:00</pubDate>\r\n <item>\r\n<author>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</author>\r\n<category>\xec\x9c\xa1\xec\x83\x81\xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</category>\r\n<title>\xec\x84\x9c\xec\x9a\xb8,\xea\xb2\xbd\xea\xb8\xb0\xeb\x8f\x84 \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4 - 2019\xeb\x85\x84 05\xec\x9b\x94 '

# %%
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
r.read(500).decode('utf-8')
# Out:
# '<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>기상청 육상 중기예보</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>\r\n<description>기상청 날씨 웹서비스</description>\r\n<language>ko</language>\r\n<generator>기상청</generator>\r\n<pubDate>2019년 05월 17일 (금)요일 18:00</pubDate>\r\n <item>\r\n<author>기상청</author>\r\n<category>육상중기예보</category>\r\n<title>서울,경기도 육상 중기예보 - 2019년 05월 '

# %%
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
xml_data = r.read().decode('utf-8')

# %%
import xml.etree.ElementTree as ET
root = ET.fromstring(xml_data)

# %%
root
# Out:
# <Element 'rss' at 0x000001A49A755228>

# %%
root.tag
# Out:
# 'rss'

# %%
root.attrib
# Out:
# {'version': '2.0'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# channel {}

# %%
for child in root.find('channel'):
    print(child.tag, child.attrib, child.text)
# Out:
# title {} 기상청 육상 중기예보
# link {} http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# description {} 기상청 날씨 웹서비스
# language {} ko
# generator {} 기상청
# pubDate {} 2019년 05월 17일 (금)요일 18:00
# item {}

# %%
root.find('channel').find('title')
# Out:
# <Element 'title' at 0x000001A49A7559A8>

# %%
root.find('channel').find('title').tag
# Out:
# 'title'

# %%
root.find('channel').find('title').attrib
# Out:
# {}

# %%
root.find('channel').find('title').text
# Out:
# '기상청 육상 중기예보'

# %%
root[0][0].tag
# Out:
# 'title'

# %%
root[0][2].tag
# Out:
# 'description'

# %%
for child in root.find('channel').find('item').find('description').find('header'):
    print(child.tag, ':', child.text)
# Out:
# title : 서울,경기도 육상중기예보
# tm : 201905171800
# wf : 기압골의 영향으로 20일은 비가 오겠고, 그 밖의 날은 고기압의 영향으로 대체로 맑은 날이 많겠습니다.   <br />기온은 평년(최저기온: 11~15℃, 최고기온: 21~25℃)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(2~4mm)과 비슷하겠습니다.<br />서해중부해상의 물결은 0.5~2.0m로 일겠습니다.

# %%
for child in root.find('channel').find('item').find('description').find('body').find('location'):
    print(child.tag, ':', child.text)
# Out:
# province : 서울ㆍ인천ㆍ경기도
# city : 서울
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :

# %%
root.find('channel').find('item').find('description').find('body').find('location').findall('data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>]

# %%
for data in root.find('channel').find('item').find('description').find('body').find('location').findall('data'):
    for child in data:
        print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통

# %%
for data in root.iter('data'):
    for child in data:
         print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통

# %%
for child in root.iter():
    print(child.tag)
# Out:
# rss
# channel
# title
# link
# description
# language
# generator
# pubDate
# item
# author
# category
# title
# link
# guid
# description
# header
# title
# tm
# wf
# body
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability

# %%
root.find('.')
# Out:
# <Element 'rss' at 0x000001A49A755228>

# %%
root.find('./channel')
# Out:
# <Element 'channel' at 0x000001A49A7554F8>

# %%
root.find('channel').find('item').find('description').find('body').find('location').findall('data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>]

# %%
root.find('./channel/item/description/body/location').findall('data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>]

# %%
root.find('.//item/description/body/location').findall('data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>]

# %%
root.find('.//location').findall('data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>]

# %%
root.findall('.//data')
# Out:
# [<Element 'data' at 0x000001A49A776E08>,
#  <Element 'data' at 0x000001A49A779098>,
#  <Element 'data' at 0x000001A49A7792C8>,
#  <Element 'data' at 0x000001A49A7794F8>,
#  <Element 'data' at 0x000001A49A779728>,
#  <Element 'data' at 0x000001A49A779958>,
#  <Element 'data' at 0x000001A49A779B88>,
#  <Element 'data' at 0x000001A49A779DB8>,
#  <Element 'data' at 0x000001A49A77D048>,
#  <Element 'data' at 0x000001A49A764548>,
#  <Element 'data' at 0x000001A49A77D138>,
#  <Element 'data' at 0x000001A49A77D368>,
#  <Element 'data' at 0x000001A49A77D598>,
#  <Element 'data' at 0x000001A49A77D8B8>,
#  <Element 'data' at 0x000001A49A77DAE8>,
#  <Element 'data' at 0x000001A49A77DD18>,
#  <Element 'data' at 0x000001A49A77DF48>,
#  <Element 'data' at 0x000001A49A7801D8>,
#  <Element 'data' at 0x000001A49A780408>,
#  <Element 'data' at 0x000001A49A780638>,
#  <Element 'data' at 0x000001A49A780868>,
#  <Element 'data' at 0x000001A49A780A98>,
#  <Element 'data' at 0x000001A49A780CC8>,
#  <Element 'data' at 0x000001A49A780EF8>,
#  <Element 'data' at 0x000001A49A783188>,
#  <Element 'data' at 0x000001A49A7833B8>,
#  <Element 'data' at 0x000001A49A7836D8>,
#  <Element 'data' at 0x000001A49A783908>,
#  <Element 'data' at 0x000001A49A783B38>,
#  <Element 'data' at 0x000001A49A783D68>,
#  <Element 'data' at 0x000001A49A783F98>,
#  <Element 'data' at 0x000001A49A786228>,
#  <Element 'data' at 0x000001A49A786458>,
#  <Element 'data' at 0x000001A49A786688>,
#  <Element 'data' at 0x000001A49A7868B8>,
#  <Element 'data' at 0x000001A49A786AE8>,
#  <Element 'data' at 0x000001A49A786D18>,
#  <Element 'data' at 0x000001A49A786F48>,
#  <Element 'data' at 0x000001A49A78A1D8>,
#  <Element 'data' at 0x000001A49A78A4F8>,
#  <Element 'data' at 0x000001A49A78A728>,
#  <Element 'data' at 0x000001A49A78A958>,
#  <Element 'data' at 0x000001A49A78AB88>,
#  <Element 'data' at 0x000001A49A78ADB8>,
#  <Element 'data' at 0x000001A49A78E048>,
#  <Element 'data' at 0x000001A49A78E278>,
#  <Element 'data' at 0x000001A49A78E4A8>,
#  <Element 'data' at 0x000001A49A78E6D8>,
#  <Element 'data' at 0x000001A49A78E908>,
#  <Element 'data' at 0x000001A49A78EB38>,
#  <Element 'data' at 0x000001A49A78ED68>,
#  <Element 'data' at 0x000001A49A78EF98>,
#  <Element 'data' at 0x000001A49A794318>,
#  <Element 'data' at 0x000001A49A794548>,
#  <Element 'data' at 0x000001A49A794778>,
#  <Element 'data' at 0x000001A49A7949A8>,
#  <Element 'data' at 0x000001A49A794BD8>,
#  <Element 'data' at 0x000001A49A794E08>,
#  <Element 'data' at 0x000001A49A798098>,
#  <Element 'data' at 0x000001A49A7982C8>,
#  <Element 'data' at 0x000001A49A7984F8>,
#  <Element 'data' at 0x000001A49A798728>,
#  <Element 'data' at 0x000001A49A798958>,
#  <Element 'data' at 0x000001A49A798B88>,
#  <Element 'data' at 0x000001A49A798DB8>,
#  <Element 'data' at 0x000001A49A79B138>,
#  <Element 'data' at 0x000001A49A79B368>,
#  <Element 'data' at 0x000001A49A79B598>,
#  <Element 'data' at 0x000001A49A79B7C8>,
#  <Element 'data' at 0x000001A49A79B9F8>,
#  <Element 'data' at 0x000001A49A79BC28>,
#  <Element 'data' at 0x000001A49A79BE58>,
#  <Element 'data' at 0x000001A49A7A10E8>,
#  <Element 'data' at 0x000001A49A7A1318>,
#  <Element 'data' at 0x000001A49A7A1548>,
#  <Element 'data' at 0x000001A49A7A1778>,
#  <Element 'data' at 0x000001A49A7A19A8>,
#  <Element 'data' at 0x000001A49A7A1BD8>,
#  <Element 'data' at 0x000001A49A7A1EF8>,
#  <Element 'data' at 0x000001A49A7A4188>,
#  <Element 'data' at 0x000001A49A7A43B8>,
#  <Element 'data' at 0x000001A49A7A45E8>,
#  <Element 'data' at 0x000001A49A7A4818>,
#  <Element 'data' at 0x000001A49A7A4A48>,
#  <Element 'data' at 0x000001A49A7A4C78>,
#  <Element 'data' at 0x000001A49A7A4EA8>,
#  <Element 'data' at 0x000001A49A7A9138>,
#  <Element 'data' at 0x000001A49A7A9368>,
#  <Element 'data' at 0x000001A49A7A9598>,
#  <Element 'data' at 0x000001A49A7A97C8>,
#  <Element 'data' at 0x000001A49A7A99F8>,
#  <Element 'data' at 0x000001A49A7A9D18>,
#  <Element 'data' at 0x000001A49A7A9F48>,
#  <Element 'data' at 0x000001A49A7AC1D8>,
#  <Element 'data' at 0x000001A49A7AC408>,
#  <Element 'data' at 0x000001A49A7AC638>,
#  <Element 'data' at 0x000001A49A7AC868>,
#  <Element 'data' at 0x000001A49A7ACA98>,
#  <Element 'data' at 0x000001A49A7ACCC8>,
#  <Element 'data' at 0x000001A49A7ACEF8>,
#  <Element 'data' at 0x000001A49A7D0188>,
#  <Element 'data' at 0x000001A49A7D03B8>,
#  <Element 'data' at 0x000001A49A7D05E8>,
#  <Element 'data' at 0x000001A49A7D0818>,
#  <Element 'data' at 0x000001A49A7D0B38>,
#  <Element 'data' at 0x000001A49A7D0D68>,
#  <Element 'data' at 0x000001A49A7D0F98>,
#  <Element 'data' at 0x000001A49A7D6228>,
#  <Element 'data' at 0x000001A49A7D6458>,
#  <Element 'data' at 0x000001A49A7D6688>,
#  <Element 'data' at 0x000001A49A7D68B8>,
#  <Element 'data' at 0x000001A49A7D6AE8>,
#  <Element 'data' at 0x000001A49A7D6D18>,
#  <Element 'data' at 0x000001A49A7D6F48>,
#  <Element 'data' at 0x000001A49A7D91D8>,
#  <Element 'data' at 0x000001A49A7D9408>,
#  <Element 'data' at 0x000001A49A7D9638>,
#  <Element 'data' at 0x000001A49A7D9958>,
#  <Element 'data' at 0x000001A49A7D9B88>,
#  <Element 'data' at 0x000001A49A7D9DB8>,
#  <Element 'data' at 0x000001A49A7DE048>,
#  <Element 'data' at 0x000001A49A7DE278>,
#  <Element 'data' at 0x000001A49A7DE4A8>,
#  <Element 'data' at 0x000001A49A7DE6D8>,
#  <Element 'data' at 0x000001A49A7DE908>,
#  <Element 'data' at 0x000001A49A7DEB38>,
#  <Element 'data' at 0x000001A49A7DED68>,
#  <Element 'data' at 0x000001A49A7DEF98>,
#  <Element 'data' at 0x000001A49A7E2228>,
#  <Element 'data' at 0x000001A49A7E2458>,
#  <Element 'data' at 0x000001A49A7E2778>,
#  <Element 'data' at 0x000001A49A7E29A8>,
#  <Element 'data' at 0x000001A49A7E2BD8>,
#  <Element 'data' at 0x000001A49A7E2E08>,
#  <Element 'data' at 0x000001A49A7E5098>,
#  <Element 'data' at 0x000001A49A7E52C8>,
#  <Element 'data' at 0x000001A49A7E54F8>,
#  <Element 'data' at 0x000001A49A7E5728>,
#  <Element 'data' at 0x000001A49A7E5958>,
#  <Element 'data' at 0x000001A49A7E5B88>,
#  <Element 'data' at 0x000001A49A7E5DB8>,
#  <Element 'data' at 0x000001A49A7E9048>,
#  <Element 'data' at 0x000001A49A7E9278>,
#  <Element 'data' at 0x000001A49A7E9598>,
#  <Element 'data' at 0x000001A49A7E97C8>,
#  <Element 'data' at 0x000001A49A7E99F8>,
#  <Element 'data' at 0x000001A49A7E9C28>,
#  <Element 'data' at 0x000001A49A7E9E58>,
#  <Element 'data' at 0x000001A49A7ED0E8>,
#  <Element 'data' at 0x000001A49A7ED318>,
#  <Element 'data' at 0x000001A49A7ED548>,
#  <Element 'data' at 0x000001A49A7ED778>,
#  <Element 'data' at 0x000001A49A7ED9A8>,
#  <Element 'data' at 0x000001A49A7EDBD8>,
#  <Element 'data' at 0x000001A49A7EDE08>,
#  <Element 'data' at 0x000001A49A7F1098>,
#  <Element 'data' at 0x000001A49A7F13B8>,
#  <Element 'data' at 0x000001A49A7F15E8>,
#  <Element 'data' at 0x000001A49A7F1818>,
#  <Element 'data' at 0x000001A49A7F1A48>,
#  <Element 'data' at 0x000001A49A7F1C78>,
#  <Element 'data' at 0x000001A49A7F1EA8>,
#  <Element 'data' at 0x000001A49A7F5138>,
#  <Element 'data' at 0x000001A49A7F5368>,
#  <Element 'data' at 0x000001A49A7F5598>,
#  <Element 'data' at 0x000001A49A7F57C8>,
#  <Element 'data' at 0x000001A49A7F59F8>,
#  <Element 'data' at 0x000001A49A7F5C28>,
#  <Element 'data' at 0x000001A49A7F5E58>,
#  <Element 'data' at 0x000001A49A7F91D8>,
#  <Element 'data' at 0x000001A49A7F9408>,
#  <Element 'data' at 0x000001A49A7F9638>,
#  <Element 'data' at 0x000001A49A7F9868>,
#  <Element 'data' at 0x000001A49A7F9A98>,
#  <Element 'data' at 0x000001A49A7F9CC8>,
#  <Element 'data' at 0x000001A49A7F9EF8>,
#  <Element 'data' at 0x000001A49A7FF188>,
#  <Element 'data' at 0x000001A49A7FF3B8>,
#  <Element 'data' at 0x000001A49A7FF5E8>,
#  <Element 'data' at 0x000001A49A7FF818>,
#  <Element 'data' at 0x000001A49A7FFA48>,
#  <Element 'data' at 0x000001A49A7FFC78>,
#  <Element 'data' at 0x000001A49A7FFF98>,
#  <Element 'data' at 0x000001A49A802228>,
#  <Element 'data' at 0x000001A49A802458>,
#  <Element 'data' at 0x000001A49A802688>,
#  <Element 'data' at 0x000001A49A8028B8>,
#  <Element 'data' at 0x000001A49A802AE8>,
#  <Element 'data' at 0x000001A49A802D18>,
#  <Element 'data' at 0x000001A49A802F48>,
#  <Element 'data' at 0x000001A49A8051D8>,
#  <Element 'data' at 0x000001A49A805408>,
#  <Element 'data' at 0x000001A49A805638>,
#  <Element 'data' at 0x000001A49A805868>,
#  <Element 'data' at 0x000001A49A805A98>,
#  <Element 'data' at 0x000001A49A805DB8>,
#  <Element 'data' at 0x000001A49A80A048>,
#  <Element 'data' at 0x000001A49A80A278>,
#  <Element 'data' at 0x000001A49A80A4A8>,
#  <Element 'data' at 0x000001A49A80A6D8>,
#  <Element 'data' at 0x000001A49A80A908>,
#  <Element 'data' at 0x000001A49A80AB38>,
#  <Element 'data' at 0x000001A49A80AD68>,
#  <Element 'data' at 0x000001A49A80AF98>,
#  <Element 'data' at 0x000001A49A810228>,
#  <Element 'data' at 0x000001A49A810458>,
#  <Element 'data' at 0x000001A49A810688>,
#  <Element 'data' at 0x000001A49A8108B8>,
#  <Element 'data' at 0x000001A49A810BD8>,
#  <Element 'data' at 0x000001A49A810E08>,
#  <Element 'data' at 0x000001A49A814098>,
#  <Element 'data' at 0x000001A49A8142C8>,
#  <Element 'data' at 0x000001A49A8144F8>,
#  <Element 'data' at 0x000001A49A814728>,
#  <Element 'data' at 0x000001A49A814958>,
#  <Element 'data' at 0x000001A49A814B88>,
#  <Element 'data' at 0x000001A49A814DB8>,
#  <Element 'data' at 0x000001A49A818048>,
#  <Element 'data' at 0x000001A49A818278>,
#  <Element 'data' at 0x000001A49A8184A8>,
#  <Element 'data' at 0x000001A49A8186D8>,
#  <Element 'data' at 0x000001A49A8189F8>,
#  <Element 'data' at 0x000001A49A818C28>,
#  <Element 'data' at 0x000001A49A818E58>,
#  <Element 'data' at 0x000001A49A81B0E8>,
#  <Element 'data' at 0x000001A49A81B318>,
#  <Element 'data' at 0x000001A49A81B548>,
#  <Element 'data' at 0x000001A49A81B778>,
#  <Element 'data' at 0x000001A49A81B9A8>,
#  <Element 'data' at 0x000001A49A81BBD8>,
#  <Element 'data' at 0x000001A49A81BE08>,
#  <Element 'data' at 0x000001A49A81F098>,
#  <Element 'data' at 0x000001A49A81F2C8>,
#  <Element 'data' at 0x000001A49A81F4F8>,
#  <Element 'data' at 0x000001A49A81F818>,
#  <Element 'data' at 0x000001A49A81FA48>,
#  <Element 'data' at 0x000001A49A81FC78>,
#  <Element 'data' at 0x000001A49A81FEA8>,
#  <Element 'data' at 0x000001A49A822138>,
#  <Element 'data' at 0x000001A49A822368>,
#  <Element 'data' at 0x000001A49A822598>,
#  <Element 'data' at 0x000001A49A8227C8>,
#  <Element 'data' at 0x000001A49A8229F8>,
#  <Element 'data' at 0x000001A49A822C28>,
#  <Element 'data' at 0x000001A49A822E58>,
#  <Element 'data' at 0x000001A49A8270E8>,
#  <Element 'data' at 0x000001A49A827318>,
#  <Element 'data' at 0x000001A49A827638>,
#  <Element 'data' at 0x000001A49A827868>,
#  <Element 'data' at 0x000001A49A827A98>,
#  <Element 'data' at 0x000001A49A827CC8>,
#  <Element 'data' at 0x000001A49A827EF8>,
#  <Element 'data' at 0x000001A49A82C188>,
#  <Element 'data' at 0x000001A49A82C3B8>,
#  <Element 'data' at 0x000001A49A82C5E8>,
#  <Element 'data' at 0x000001A49A82C818>,
#  <Element 'data' at 0x000001A49A82CA48>,
#  <Element 'data' at 0x000001A49A82CC78>,
#  <Element 'data' at 0x000001A49A82CEA8>,
#  <Element 'data' at 0x000001A49A82F138>,
#  <Element 'data' at 0x000001A49A82F458>,
#  <Element 'data' at 0x000001A49A82F688>,
#  <Element 'data' at 0x000001A49A82F8B8>,
#  <Element 'data' at 0x000001A49A82FAE8>,
#  <Element 'data' at 0x000001A49A82FD18>,
#  <Element 'data' at 0x000001A49A82FF48>,
#  <Element 'data' at 0x000001A49A8331D8>,
#  <Element 'data' at 0x000001A49A833408>,
#  <Element 'data' at 0x000001A49A833638>,
#  <Element 'data' at 0x000001A49A833868>,
#  <Element 'data' at 0x000001A49A833A98>,
#  <Element 'data' at 0x000001A49A833CC8>,
#  <Element 'data' at 0x000001A49A833EF8>,
#  <Element 'data' at 0x000001A49A837278>,
#  <Element 'data' at 0x000001A49A8374A8>,
#  <Element 'data' at 0x000001A49A8376D8>,
#  <Element 'data' at 0x000001A49A837908>,
#  <Element 'data' at 0x000001A49A837B38>,
#  <Element 'data' at 0x000001A49A837D68>,
#  <Element 'data' at 0x000001A49A837F98>,
#  <Element 'data' at 0x000001A49A83C228>,
#  <Element 'data' at 0x000001A49A83C458>,
#  <Element 'data' at 0x000001A49A83C688>,
#  <Element 'data' at 0x000001A49A83C8B8>,
#  <Element 'data' at 0x000001A49A83CAE8>,
#  <Element 'data' at 0x000001A49A83CD18>,
#  <Element 'data' at 0x000001A49A840098>,
#  <Element 'data' at 0x000001A49A8402C8>,
#  <Element 'data' at 0x000001A49A8404F8>,
#  <Element 'data' at 0x000001A49A840728>,
#  <Element 'data' at 0x000001A49A840958>,
#  <Element 'data' at 0x000001A49A840B88>,
#  <Element 'data' at 0x000001A49A840DB8>,
#  <Element 'data' at 0x000001A49A843048>,
#  <Element 'data' at 0x000001A49A843278>,
#  <Element 'data' at 0x000001A49A8434A8>,
#  <Element 'data' at 0x000001A49A8436D8>,
#  <Element 'data' at 0x000001A49A843908>,
#  <Element 'data' at 0x000001A49A843B38>,
#  <Element 'data' at 0x000001A49A843E58>,
#  <Element 'data' at 0x000001A49A8470E8>,
#  <Element 'data' at 0x000001A49A847318>,
#  <Element 'data' at 0x000001A49A847548>,
#  <Element 'data' at 0x000001A49A847778>,
#  <Element 'data' at 0x000001A49A8479A8>,
#  <Element 'data' at 0x000001A49A847BD8>,
#  <Element 'data' at 0x000001A49A847E08>,
#  <Element 'data' at 0x000001A49A84B098>,
#  <Element 'data' at 0x000001A49A84B2C8>,
#  <Element 'data' at 0x000001A49A84B4F8>,
#  <Element 'data' at 0x000001A49A84B728>,
#  <Element 'data' at 0x000001A49A84B958>,
#  <Element 'data' at 0x000001A49A84BC78>,
#  <Element 'data' at 0x000001A49A84BEA8>,
#  <Element 'data' at 0x000001A49A84F138>,
#  <Element 'data' at 0x000001A49A84F368>,
#  <Element 'data' at 0x000001A49A84F598>,
#  <Element 'data' at 0x000001A49A84F7C8>,
#  <Element 'data' at 0x000001A49A84F9F8>,
#  <Element 'data' at 0x000001A49A84FC28>,
#  <Element 'data' at 0x000001A49A84FE58>,
#  <Element 'data' at 0x000001A49A8540E8>,
#  <Element 'data' at 0x000001A49A854318>,
#  <Element 'data' at 0x000001A49A854548>,
#  <Element 'data' at 0x000001A49A854778>,
#  <Element 'data' at 0x000001A49A854A98>,
#  <Element 'data' at 0x000001A49A854CC8>,
#  <Element 'data' at 0x000001A49A854EF8>,
#  <Element 'data' at 0x000001A49A858188>,
#  <Element 'data' at 0x000001A49A8583B8>,
#  <Element 'data' at 0x000001A49A8585E8>,
#  <Element 'data' at 0x000001A49A858818>,
#  <Element 'data' at 0x000001A49A858A48>,
#  <Element 'data' at 0x000001A49A858C78>,
#  <Element 'data' at 0x000001A49A858EA8>,
#  <Element 'data' at 0x000001A49A85C138>,
#  <Element 'data' at 0x000001A49A85C368>,
#  <Element 'data' at 0x000001A49A85C598>,
#  <Element 'data' at 0x000001A49A85C8B8>,
#  <Element 'data' at 0x000001A49A85CAE8>,
#  <Element 'data' at 0x000001A49A85CD18>,
#  <Element 'data' at 0x000001A49A85CF48>,
#  <Element 'data' at 0x000001A49A8611D8>,
#  <Element 'data' at 0x000001A49A861408>,
#  <Element 'data' at 0x000001A49A861638>,
#  <Element 'data' at 0x000001A49A861868>,
#  <Element 'data' at 0x000001A49A861A98>,
#  <Element 'data' at 0x000001A49A861CC8>,
#  <Element 'data' at 0x000001A49A861EF8>,
#  <Element 'data' at 0x000001A49A864188>,
#  <Element 'data' at 0x000001A49A8643B8>,
#  <Element 'data' at 0x000001A49A8646D8>,
#  <Element 'data' at 0x000001A49A864908>,
#  <Element 'data' at 0x000001A49A864B38>,
#  <Element 'data' at 0x000001A49A864D68>,
#  <Element 'data' at 0x000001A49A864F98>,
#  <Element 'data' at 0x000001A49A86A228>,
#  <Element 'data' at 0x000001A49A86A458>,
#  <Element 'data' at 0x000001A49A86A688>,
#  <Element 'data' at 0x000001A49A86A8B8>,
#  <Element 'data' at 0x000001A49A86AAE8>,
#  <Element 'data' at 0x000001A49A86AD18>,
#  <Element 'data' at 0x000001A49A86AF48>,
#  <Element 'data' at 0x000001A49A86D1D8>,
#  <Element 'data' at 0x000001A49A86D4F8>,
#  <Element 'data' at 0x000001A49A86D728>,
#  <Element 'data' at 0x000001A49A86D958>,
#  <Element 'data' at 0x000001A49A86DB88>,
#  <Element 'data' at 0x000001A49A86DDB8>,
#  <Element 'data' at 0x000001A49A872048>,
#  <Element 'data' at 0x000001A49A872278>,
#  <Element 'data' at 0x000001A49A8724A8>,
#  <Element 'data' at 0x000001A49A8726D8>,
#  <Element 'data' at 0x000001A49A872908>,
#  <Element 'data' at 0x000001A49A872B38>,
#  <Element 'data' at 0x000001A49A872D68>,
#  <Element 'data' at 0x000001A49A872F98>,
#  <Element 'data' at 0x000001A49A875318>,
#  <Element 'data' at 0x000001A49A875548>,
#  <Element 'data' at 0x000001A49A875778>,
#  <Element 'data' at 0x000001A49A8759A8>,
#  <Element 'data' at 0x000001A49A875BD8>,
#  <Element 'data' at 0x000001A49A875E08>,
#  <Element 'data' at 0x000001A49A879098>,
#  <Element 'data' at 0x000001A49A8792C8>,
#  <Element 'data' at 0x000001A49A8794F8>,
#  <Element 'data' at 0x000001A49A879728>,
#  <Element 'data' at 0x000001A49A879958>,
#  <Element 'data' at 0x000001A49A879B88>,
#  <Element 'data' at 0x000001A49A879DB8>,
#  <Element 'data' at 0x000001A49A87D138>,
#  <Element 'data' at 0x000001A49A87D368>,
#  <Element 'data' at 0x000001A49A87D598>,
#  <Element 'data' at 0x000001A49A87D7C8>,
#  <Element 'data' at 0x000001A49A87D9F8>,
#  <Element 'data' at 0x000001A49A87DC28>,
#  <Element 'data' at 0x000001A49A87DE58>,
#  <Element 'data' at 0x000001A49A8800E8>,
#  <Element 'data' at 0x000001A49A880318>,
#  <Element 'data' at 0x000001A49A880548>,
#  <Element 'data' at 0x000001A49A880778>,
#  <Element 'data' at 0x000001A49A8809A8>,
#  <Element 'data' at 0x000001A49A880BD8>,
#  <Element 'data' at 0x000001A49A880EF8>,
#  <Element 'data' at 0x000001A49A885188>,
#  <Element 'data' at 0x000001A49A8853B8>,
#  <Element 'data' at 0x000001A49A8855E8>,
#  <Element 'data' at 0x000001A49A885818>,
#  <Element 'data' at 0x000001A49A885A48>,
#  <Element 'data' at 0x000001A49A885C78>,
#  <Element 'data' at 0x000001A49A885EA8>,
#  <Element 'data' at 0x000001A49A889138>,
#  <Element 'data' at 0x000001A49A889368>,
#  <Element 'data' at 0x000001A49A889598>,
#  <Element 'data' at 0x000001A49A8897C8>,
#  <Element 'data' at 0x000001A49A8899F8>,
#  <Element 'data' at 0x000001A49A889D18>,
#  <Element 'data' at 0x000001A49A889F48>,
#  <Element 'data' at 0x000001A49A88D1D8>,
#  <Element 'data' at 0x000001A49A88D408>,
#  <Element 'data' at 0x000001A49A88D638>,
#  <Element 'data' at 0x000001A49A88D868>,
#  <Element 'data' at 0x000001A49A88DA98>,
#  <Element 'data' at 0x000001A49A88DCC8>,
#  <Element 'data' at 0x000001A49A88DEF8>,
#  <Element 'data' at 0x000001A49A892188>,
#  <Element 'data' at 0x000001A49A8923B8>,
#  <Element 'data' at 0x000001A49A8925E8>,
#  <Element 'data' at 0x000001A49A892818>,
#  <Element 'data' at 0x000001A49A892B38>,
#  <Element 'data' at 0x000001A49A892D68>,
#  <Element 'data' at 0x000001A49A892F98>,
#  <Element 'data' at 0x000001A49A895228>,
#  <Element 'data' at 0x000001A49A895458>,
#  <Element 'data' at 0x000001A49A895688>,
#  <Element 'data' at 0x000001A49A8958B8>,
#  <Element 'data' at 0x000001A49A895AE8>,
#  <Element 'data' at 0x000001A49A895D18>,
#  <Element 'data' at 0x000001A49A895F48>,
#  <Element 'data' at 0x000001A49A8991D8>,
#  <Element 'data' at 0x000001A49A899408>,
#  <Element 'data' at 0x000001A49A899638>,
#  <Element 'data' at 0x000001A49A899958>,
#  <Element 'data' at 0x000001A49A899B88>,
#  <Element 'data' at 0x000001A49A899DB8>,
#  <Element 'data' at 0x000001A49A89E048>,
#  <Element 'data' at 0x000001A49A89E278>,
#  <Element 'data' at 0x000001A49A89E4A8>,
#  <Element 'data' at 0x000001A49A89E6D8>,
#  <Element 'data' at 0x000001A49A89E908>,
#  <Element 'data' at 0x000001A49A89EB38>,
#  <Element 'data' at 0x000001A49A89ED68>,
#  <Element 'data' at 0x000001A49A89EF98>,
#  <Element 'data' at 0x000001A49A8A2228>,
#  <Element 'data' at 0x000001A49A8A2458>]

# %%
for data in root.findall('.//data'):
    for child in data:
        print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통
