# %%
import urllib
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')

# %%
r.status
# Out:
# 200

# %%
r

# %%
r.read(500)
# Out:
# b'<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>\r\n<description>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xeb\x82\xa0\xec\x94\xa8 \xec\x9b\xb9\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4</description>\r\n<language>ko</language>\r\n<generator>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</generator>\r\n<pubDate>2019\xeb\x85\x84 05\xec\x9b\x94 17\xec\x9d\xbc (\xea\xb8\x88)\xec\x9a\x94\xec\x9d\xbc 18:00</pubDate>\r\n <item>\r\n<author>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</author>\r\n<category>\xec\x9c\xa1\xec\x83\x81\xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</category>\r\n<title>\xec\x84\x9c\xec\x9a\xb8,\xea\xb2\xbd\xea\xb8\xb0\xeb\x8f\x84 \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4 - 2019\xeb\x85\x84 05\xec\x9b\x94 '

# %%
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
r.read(500).decode('utf-8')
# Out:
# '<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>기상청 육상 중기예보</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>\r\n<description>기상청 날씨 웹서비스</description>\r\n<language>ko</language>\r\n<generator>기상청</generator>\r\n<pubDate>2019년 05월 17일 (금)요일 18:00</pubDate>\r\n <item>\r\n<author>기상청</author>\r\n<category>육상중기예보</category>\r\n<title>서울,경기도 육상 중기예보 - 2019년 05월 '

# %%
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
xml_data = r.read().decode('utf-8')

# %%
import xml.etree.ElementTree as ET
root = ET.fromstring(xml_data)

# %%
root
# Out:
# <Element 'rss' at 0x000001BCEDD41548>

# %%
root.tag
# Out:
# 'rss'

# %%
root.attrib
# Out:
# {'version': '2.0'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# channel {}

# %%
for child in root.find('channel'):
    print(child.tag, child.attrib, child.text)
# Out:
# title {} 기상청 육상 중기예보
# link {} http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# description {} 기상청 날씨 웹서비스
# language {} ko
# generator {} 기상청
# pubDate {} 2019년 05월 17일 (금)요일 18:00
# item {}

# %%
root.find('channel').find('title')
# Out:
# <Element 'title' at 0x000001BCEDD520E8>

# %%
root.find('channel').find('title').tag
# Out:
# 'title'

# %%
root.find('channel').find('title').attrib
# Out:
# {}

# %%
root.find('channel').find('title').text
# Out:
# '기상청 육상 중기예보'

# %%
root[0][0].tag
# Out:
# 'title'

# %%
root[0][2].tag
# Out:
# 'description'

# %%
for child in root.find('channel').find('item').find('description').find('header'):
    print(child.tag, ':', child.text)
# Out:
# title : 서울,경기도 육상중기예보
# tm : 201905171800
# wf : 기압골의 영향으로 20일은 비가 오겠고, 그 밖의 날은 고기압의 영향으로 대체로 맑은 날이 많겠습니다.   <br />기온은 평년(최저기온: 11~15℃, 최고기온: 21~25℃)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(2~4mm)과 비슷하겠습니다.<br />서해중부해상의 물결은 0.5~2.0m로 일겠습니다.

# %%
for child in root.find('channel').find('item').find('description').find('body').find('location'):
    print(child.tag, ':', child.text)
# Out:
# province : 서울ㆍ인천ㆍ경기도
# city : 서울
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :

# %%
root.find('channel').find('item').find('description').find('body').find('location').findall('data')
# Out:
# [<Element 'data' at 0x000001BCEDD924F8>,
#  <Element 'data' at 0x000001BCEDD92728>,
#  <Element 'data' at 0x000001BCEDD92958>,
#  <Element 'data' at 0x000001BCEDD92B88>,
#  <Element 'data' at 0x000001BCEDD92DB8>,
#  <Element 'data' at 0x000001BCEDD97048>,
#  <Element 'data' at 0x000001BCEDD97278>,
#  <Element 'data' at 0x000001BCEDD974A8>,
#  <Element 'data' at 0x000001BCEDD976D8>,
#  <Element 'data' at 0x000001BCEDD52B38>,
#  <Element 'data' at 0x000001BCEDD977C8>,
#  <Element 'data' at 0x000001BCEDD979F8>,
#  <Element 'data' at 0x000001BCEDD97C28>]

# %%
for data in root.find('channel').find('item').find('description').find('body').find('location').findall('data'):
    for child in data:
        print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통

# %%
for data in root.iter('data'):
    for child in data:
         print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 11
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 14
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 17
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 25
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 13
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 17
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 9
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 8
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 8
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 10
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 31
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 12
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 13
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 12
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 13
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 14
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 13
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 13
# tmx : 26
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 16
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 16
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 11
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 30
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 15
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 15
# tmx : 20
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 27
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 11
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 14
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 00:00
# wf : 흐리고 비
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-20 12:00
# wf : 구름많음
# tmn : 17
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 00:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-21 12:00
# wf : 맑음
# tmn : 11
# tmx : 23
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 00:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-22 12:00
# wf : 맑음
# tmn : 9
# tmx : 25
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 00:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-23 12:00
# wf : 맑음
# tmn : 10
# tmx : 28
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 00:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A02
# tmEf : 2019-05-24 12:00
# wf : 맑음
# tmn : 12
# tmx : 29
# reliability : 보통
# mode : A01
# tmEf : 2019-05-25 00:00
# wf : 맑음
# tmn : 13
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-26 00:00
# wf : 구름많음
# tmn : 14
# tmx : 28
# reliability : 보통
# mode : A01
# tmEf : 2019-05-27 00:00
# wf : 구름많음
# tmn : 13
# tmx : 28
# reliability : 보통

# %%
for child in root.iter():
    print(child.tag)
# Out:
# rss
# channel
# title
# link
# description
# language
# generator
# pubDate
# item
# author
# category
# title
# link
# guid
# description
# header
# title
# tm
# wf
# body
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# location
# province
# city
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability
# data
# mode
# tmEf
# wf
# tmn
# tmx
# reliability

# %%
root.find('.')
# Out:
# <Element 'rss' at 0x000001BCEDD41548>

# %%
root.find('./channel')
# Out:
# <Element 'channel' at 0x000001BCEDD41BD8>

# %%
root.find('channel').find('item').find('description').find('body').find('location').findall('data')
# Out:
# [<Element 'data' at 0x000001BCEDD924F8>,
#  <Element 'data' at 0x000001BCEDD92728>,
#  <Element 'data' at 0x000001BCEDD92958>,
#  <Element 'data' at 0x000001BCEDD92B88>,
#  <Element 'data' at 0x000001BCEDD92DB8>,
#  <Element 'data' at 0x000001BCEDD97048>,
#  <Element 'data' at 0x000001BCEDD97278>,
#  <Element 'data' at 0x000001BCEDD974A8>,
#  <Element 'data' at 0x000001BCEDD976D8>,
#  <Element 'data' at 0x000001BCEDD52B38>,
#  <Element 'data' at 0x000001BCEDD977C8>,
#  <Element 'data' at 0x000001BCEDD979F8>,
#  <Element 'data' at 0x000001BCEDD97C28>]

# %%
root.find('./channel/item/description/body/location').findall('data')
# Out:
# [<Element 'data' at 0x000001BCEDD924F8>,
#  <Element 'data' at 0x000001BCEDD92728>,
#  <Element 'data' at 0x000001BCEDD92958>,
#  <Element 'data' at 0x000001BCEDD92B88>,
#  <Element 'data' at 0x000001BCEDD92DB8>,
#  <Element 'data' at 0x000001BCEDD97048>,
#  <Element 'data' at 0x000001BCEDD97278>,
#  <Element 'data' at 0x000001BCEDD974A8>,
#  <Element 'data' at 0x000001BCEDD976D8>,
#  <Element 'data' at 0x000001BCEDD52B38>,
#  <Element 'data' at 0x000001BCEDD977C8>,
#  <Element 'data' at 0x000001BCEDD979F8>,
#  <Element 'data' at 0x000001BCEDD97C28>]
