# %%
import urllib
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')

# %%
r.status # 200 이 출력되면 정상.
# Out:
# 200

# %%
xml_data = r.read().decode('utf-8')

# %%
import xml.etree.ElementTree as ET 
root = ET.fromstring(xml_data)

# %%
root
# Out:
# <Element 'rss' at 0x000001502F7CED68>

# %%
root.tag
# Out:
# 'rss'

# %%
root.attrib
# Out:
# {'version': '2.0'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# channel {}

# %%
for child in root.find('channel'):
    print(child.tag, child.attrib, child.text)
# Out:
# title {} 기상청 육상 중기예보
# link {} http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# description {} 기상청 날씨 웹서비스
# language {} ko
# generator {} 기상청
# pubDate {} 2019년 05월 02일 (목)요일 18:00
# item {}

# %%
root.find('channel').find('title')
# Out:
# <Element 'title' at 0x000001502F7F1098>

# %%
root.find('channel').find('title').tag
# Out:
# 'title'

# %%
root.find('channel').find('title').attrib
# Out:
# {}

# %%
root.find('channel').find('title').text
# Out:
# '기상청 육상 중기예보'

# %%
for child in root.find('channel').find('item').find('description').find('header'):
    print(child.tag, ':', child.text)
# Out:
# title : 서울,경기도 육상중기예보
# tm : 201905021800
# wf : 이번 예보기간은 고기압의 영향으로 맑은 날이 많겠습니다.   <br />기온은 평년(최저기온: 9~13℃, 최고기온: 20~22℃)과 비슷하겠습니다.<br />강수량은 평년(3~6mm)보다 적겠습니다.<br />서해중부해상의 물결은 0.5~2.0m로 일겠습니다.

# %%
for child in root.find('channel').find('item').find('description').find('body').find('location'):
    print(child.tag, ':', child.text)
# Out:
# province : 서울ㆍ인천ㆍ경기도
# city : 서울
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :

# %%
for data in root.find('channel').find('item').find('description').find('body').find('location').findall('data'):
    print(data.tag, ':', data.text)
# Out:
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :
#
# data :

# %%
root.find('channel').find('item').find('description').find('body').find('location').findall('data')
# Out:
# [<Element 'data' at 0x000001502F816B38>,
#  <Element 'data' at 0x000001502F816D68>,
#  <Element 'data' at 0x000001502F816F98>,
#  <Element 'data' at 0x000001502F81E228>,
#  <Element 'data' at 0x000001502F81E458>,
#  <Element 'data' at 0x000001502F81E688>,
#  <Element 'data' at 0x000001502F81E8B8>,
#  <Element 'data' at 0x000001502F81EAE8>,
#  <Element 'data' at 0x000001502F81ED18>,
#  <Element 'data' at 0x000001502F81EF48>,
#  <Element 'data' at 0x000001502F8411D8>,
#  <Element 'data' at 0x000001502F841408>,
#  <Element 'data' at 0x000001502F841638>]

# %%
for data in root.find('channel').find('item').find('description').find('body').find('location').findall('data'):
    for child in data:
        print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통

# %%
root[0][2].tag
# Out:
# 'description'

# %%
for data in root.iter('data'):
    for child in data:
         print(child.tag, ':', child.text)
# Out:
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 높음
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 높음
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 11
# tmx : 19
# reliability : 높음
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 11
# tmx : 19
# reliability : 높음
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 12
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 12
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 18
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 18
# reliability : 보통
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 13
# tmx : 19
# reliability : 보통
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 18
# reliability : 보통
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 13
# tmx : 19
# reliability : 보통
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn :
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통

# %%
for child in root.iter():
    print(child.tag, ':', child.text)
# Out:
# rss :
#
# channel :
#
# title : 기상청 육상 중기예보
# link : http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# description : 기상청 날씨 웹서비스
# language : ko
# generator : 기상청
# pubDate : 2019년 05월 02일 (목)요일 18:00
# item :
#
# author : 기상청
# category : 육상중기예보
# title : 서울,경기도 육상 중기예보 - 2019년 05월 02일 (목)요일 18:00 발표
# link : http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# guid : http://www.kma.go.kr/weather/forecast/mid-term_02.jsp
# description :
#
# header :
#
# title : 서울,경기도 육상중기예보
# tm : 201905021800
# wf : 이번 예보기간은 고기압의 영향으로 맑은 날이 많겠습니다.   <br />기온은 평년(최저기온: 9~13℃, 최고기온: 20~22℃)과 비슷하겠습니다.<br />강수량은 평년(3~6mm)보다 적겠습니다.<br />서해중부해상의 물결은 0.5~2.0m로 일겠습니다.
# body :
#
#
#
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 서울
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 인천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 11
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 11
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 12
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 12
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 18
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 18
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 13
# tmx : 19
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 18
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 13
# tmx : 19
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 수원
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 파주
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 8
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 8
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 9
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 이천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 평택
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 백령도
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 16
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 16
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 17
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 17
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 18
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 18
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 18
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 18
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 18
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 18
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 18
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 17
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 18
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 과천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 광명
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 14
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 14
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 12
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 12
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 12
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 13
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 강화
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 19
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 7
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 7
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 19
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 19
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 김포
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 20
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 시흥
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 19
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 20
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 안산
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 부천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 12
# tmx : 20
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 의정부
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 고양
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 12
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 양주
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 9
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 9
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 6
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 6
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 동두천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 6
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 6
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 연천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 5
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 5
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 4
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 4
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 포천
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 6
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 6
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 가평
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 9
# tmx : 26
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 9
# tmx : 26
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 5
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 5
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 3
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 3
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 4
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 4
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 5
# tmx : 25
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 5
# tmx : 25
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 7
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 구리
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 남양주
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 5
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 6
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 6
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 양평
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 하남
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 안양
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 오산
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 화성
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 11
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 21
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 성남
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 12
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 12
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 12
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 의왕
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 14
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 14
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 9
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 12
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 군포
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 13
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 10
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 11
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 12
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 12
# tmx : 23
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 안성
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 10
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 용인
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 24
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 20
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 21
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 22
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 20
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 광주
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 7
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 7
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 7
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 25
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 25
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 22
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 11
# tmx : 22
# reliability : 보통
# location :
#
# province : 서울ㆍ인천ㆍ경기도
# city : 여주
# data :
#
# mode : A02
# tmEf : 2019-05-05 00:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-05 12:00
# wf : 구름많음
# tmn : 11
# tmx : 25
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-06 00:00
# wf : 구름많음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-06 12:00
# wf : 맑음
# tmn : 8
# tmx : 21
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-07 00:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-07 12:00
# wf : 맑음
# tmn : 6
# tmx : 22
# reliability : 높음
# data :
#
# mode : A02
# tmEf : 2019-05-08 00:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-08 12:00
# wf : 맑음
# tmn : 8
# tmx : 23
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 00:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A02
# tmEf : 2019-05-09 12:00
# wf : 구름많음
# tmn : 8
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-10 00:00
# wf : 맑음
# tmn : 9
# tmx : 24
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-11 00:00
# wf : 맑음
# tmn : 10
# tmx : 21
# reliability : 보통
# data :
#
# mode : A01
# tmEf : 2019-05-12 00:00
# wf : 구름많음
# tmn : 10
# tmx : 23
# reliability : 보통
